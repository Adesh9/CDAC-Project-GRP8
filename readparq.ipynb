# %%
# Intialization
import os
import sys

os.environ["SPARK_HOME"] = "/home/talentum/spark"
os.environ["PYLIB"] = os.environ["SPARK_HOME"] + "/python/lib"
# In below two lines, use /usr/bin/python2.7 if you want to use Python 2
os.environ["PYSPARK_PYTHON"] = "/usr/bin/python3.6" 
os.environ["PYSPARK_DRIVER_PYTHON"] = "/usr/bin/python3"
sys.path.insert(0, os.environ["PYLIB"] +"/py4j-0.10.7-src.zip")
sys.path.insert(0, os.environ["PYLIB"] +"/pyspark.zip")

# NOTE: Whichever package you want mention here.
# os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.databricks:spark-xml_2.11:0.6.0 pyspark-shell' 
# os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-avro_2.11:2.4.0 pyspark-shell'
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.databricks:spark-xml_2.11:0.6.0,org.apache.spark:spark-avro_2.11:2.4.3 pyspark-shell'
# os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.databricks:spark-xml_2.11:0.6.0,org.apache.spark:spark-avro_2.11:2.4.0 pyspark-shell'

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("ReadParquet") \
    .getOrCreate()

df = spark.read.parquet(
    "file:///home/talentum/project/parquet_output/reviews_nlp_compare"
)

df.select(
    "clean_summary",
    "lemma_summary",
    "clean_text",
    "lemma_text",
    "score"
).show(5, truncate=False)

spark.stop()
# Out:
# +---------------------------------+---------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |clean_summary                    |lemma_summary                    |clean_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |lemma_text                                                                                                                                                                                                                                                                               |score|
# +---------------------------------+---------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |love this                        |love                             |this was such a delicious tasting drink   i poured it into a cup of ice and drank it right up   it was bursting with flavor and completely satisfied my taste buds   i definitely will be trying this great drink again and recommend it   i also loved the packaging for this                                                                                                                                                                                                                                                           |delicious taste drink    pour cup ice drink right    burst flavor completely satisfy taste bud    definitely try great drink recommend    love packaging                                                                                                                                 |5    |
# |decent but not the best          |decent good                      |pros   cats liked it  good ingredients  small pellets so easy to eat with kittens or cats who have lost their teeth  cons    much more expensive than the other brands per lb and also my cats needed to eat more of this than my innova evo which made it more expensive per meal   not as good of ingredients as evo   very small pellets so the cats didnt even have to chew at all meaning less jaw muscle workout   all in all  i would not purchase this again  i rather spend the money buying evo until p g changes their formula|pro    cat like   good ingredient   small pellet easy eat kitten cat lose tooth   con     expensive brand lb cat need eat innova evo expensive meal    good ingredient evo    small pellet cat not chew meaning jaw muscle workout      purchase   spend money buy evo p g change formula|3    |
# |great for your dog s teeth       |great dog s tooth                |been buying these for years at the recommendation of my vet   i hate to brush my dogs  teeth and i find these chews help keep their teeth and gums in good shape                                                                                                                                                                                                                                                                                                                                                                         |buy year recommendation vet    hate brush dog   tooth find chews help tooth gum good shape                                                                                                                                                                                               |5    |
# |amish country lady finger popcorn|amish country lady finger popcorn|my daughter makes popcorn in her whirly pop   we all agree this is the very best popcorn we have ever had   medium sized kernels and very flavorful                                                                                                                                                                                                                                                                                                                                                                                      |daughter make popcorn whirly pop    agree good popcorn    medium sized kernel flavorful                                                                                                                                                                                                  |5    |
# |pamela s pancake   baking mix    |pamela s pancake    bake mix     |use this mix   your family will never know it s gluten free   absolutely the best pancake waffle mix out there for celiacs   yum                                                                                                                                                                                                                                                                                                                                                                                                         |use mix    family know s gluten free    absolutely good pancake waffle mix celiac    yum                                                                                                                                                                                                 |5    |
# +---------------------------------+---------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# only showing top 5 rows
